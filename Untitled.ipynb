# %%
import train

# %%
#python train.py --epochs 8 --batch_size 128 --lr 2e-4 --max_len 8
trainTest = train(--epochs 8 --batch_size 128 --lr 2e-4 --max_len 8)
# Out:
#   Cell In[5], line 2
#     trainTest = train(--epochs 8 --batch_size 128 --lr 2e-4 --max_len 8)
#                       ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
